# %% [markdown]
# # --- Session 12 ---
# # tkInter
# # واسط گرافیکی tkInter

# %%
import tkinter as tk  # Import Tkinter library

root = tk.Tk()  # Create the main window
root.title("پنجره اصلی")  # Set the window title

root.mainloop()  # Start the event loop

# %%
import tkinter as tk

root = tk.Tk()




root.title("مثال برچسب")

label = tk.Label(root, text="سلام به دنیای Tkinter!")
label.pack()  # اضافه کردن برچسب به پنجره




root.mainloop()

# %%
import tkinter as tk

def greet():
    print("سلام!")

root = tk.Tk()
root.title("مثال دکمه")

button = tk.Button(root, text="کلیک کنید", command=greet)
button.pack()

root.mainloop()

# %%
import tkinter as tk

def show_entry():
    print(entry.get())

root = tk.Tk()
root.title("مثال ورودی")

entry = tk.Entry(root)
entry.pack()

button = tk.Button(root, text="نمایش ورودی", command=show_entry)
button.pack()

root.mainloop()

# %%
import tkinter as tk

root = tk.Tk()

label1 = tk.Label(root, text="Label 1")
label1.pack()

label2 = tk.Label(root, text="Label 2")
label2.pack()

root.mainloop()

# %%
import tkinter as tk

root = tk.Tk()

label1 = tk.Label(root, text="Label 1")
label1.grid(row=0, column=0)

label2 = tk.Label(root, text="Label 2")
label2.grid(row=0, column=1)

root.mainloop()

# %%
import tkinter as tk

root = tk.Tk()
root.geometry("800x500")  # Set the window size to 300x500
root.resizable(False,False)

label1 = tk.Label(root, text="Label 1")
label1.place(x=50, y=50)

label2 = tk.Label(root, text="Label 2")
label2.place(x=100, y=100)

root.mainloop()

# %%
import tkinter as tk

root = tk.Tk()

label = tk.Label(root, text="برچسب با استایل", font=("Arial", 16), fg="red", bg="yellow")
label.pack()

root.mainloop()

# %%
import tkinter as tk

def on_click(event):
    print("کلیک شد!")

root = tk.Tk()

root.bind("<Button-1>", on_click)

root.mainloop()

# %%
import tkinter as tk

root = tk.Tk()

menubar = tk.Menu(root)

filemenu = tk.Menu(menubar, tearoff=0)
filemenu.add_command(label="باز کردن")
filemenu.add_command(label="ذخیره")
filemenu.add_separator()
filemenu.add_command(label="خروج", command=root.quit)

menubar.add_cascade(label="فایل", menu=filemenu)

root.config(menu=menubar)

root.mainloop()

# %%
# کم کاربرد
# ویجت Canvas برای رسم اشکال، خطوط، و تصاویر استفاده می‌شود:


import tkinter as tk

root = tk.Tk()

canvas = tk.Canvas(root, width=200, height=200)
canvas.pack()

canvas.create_line(0, 0, 200, 200, fill="blue")
canvas.create_rectangle(50, 50, 150, 150, fill="red")

root.mainloop()

# %%
import tkinter as tk
from tkinter import messagebox

# تابع نمایش انتخاب جنسیت
def show_gender():
    selected_gender = gender.get()
    if selected_gender == "male":
        messagebox.showinfo("انتخاب", "شما مرد را انتخاب کردید.")
    elif selected_gender == "female":
        messagebox.showinfo("انتخاب", "شما زن را انتخاب کردید.")

# ایجاد پنجره اصلی
root = tk.Tk()
root.title("انتخاب جنسیت")

# مقدار پیش‌فرض جنسیت
gender = tk.StringVar()
taahol = tk.StringVar()
gender.set("female")  # مقدار پیش‌فرض
taahol.set("no")


# برچسب راهنما
label = tk.Label(root, text="لطفاً جنسیت خود را انتخاب کنید:")
label.pack(padx=50,pady=20)

# دکمه‌های Radio برای انتخاب مرد یا زن
male_radio = tk.Radiobutton(root, text="مرد", variable=gender, value="male")
female_radio = tk.Radiobutton(root, text="زن", variable=gender, value="female")
unknown_radio = tk.Radiobutton(root, text="نامشخص", variable=gender, value="unknown")

male_radio.pack(pady=5)
female_radio.pack(pady=5)
unknown_radio.pack(pady=5)

label2 = tk.Label(root, text="لطفاً مجرد بودن خود را انتخاب کنید:")
single = tk.Radiobutton(root, text="بله", variable=taahol, value="yes")
Notsingle = tk.Radiobutton(root, text="خیر", variable=taahol, value="no")


label2.pack(padx=50,pady=20)
single.pack(pady=5)
Notsingle.pack(pady=5)





# دکمه برای نمایش انتخاب
button = tk.Button(root, text="انتخاب جنسیت", command=show_gender)
button.pack(pady=10)

# اجرای حلقه اصلی برنامه
root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 54
#      51 button.pack(pady=10)
#      53 # اجرای حلقه اصلی برنامه
# ---> 54 root.mainloop()
#
# File c:\Users\amirl\AppData\Local\Programs\Python\Python312\Lib\tkinter\__init__.py:1504, in Misc.mainloop(self, n)
#    1502 def mainloop(self, n=0):
#    1503     """Call the mainloop of Tk."""
# -> 1504     self.tk.mainloop(n)
#
# KeyboardInterrupt:

# %%
import tkinter as tk
from tkinter import messagebox

# تابع نمایش انتخاب‌ها
def show_selections():
    selections = []
    if python_var.get():
        selections.append("پایتون")
    if java_var.get():
        selections.append("جاوا")
    if cpp_var.get():
        selections.append("C++")
    
    if selections:
        messagebox.showwarning("انتخاب‌ها", "شما انتخاب کردید: " + ", ".join(selections))
    else:
        messagebox.showwarning("هیچ انتخابی", "لطفاً حداقل یک گزینه را انتخاب کنید.")

# ایجاد پنجره اصلی
root = tk.Tk()
root.title("انتخاب زبان‌های برنامه‌نویسی")

# متغیرهای CheckButton
python_var = tk.BooleanVar()
java_var = tk.BooleanVar()
cpp_var = tk.BooleanVar()

# برچسب راهنما
label = tk.Label(root, text="لطفاً زبان‌های برنامه‌نویسی مورد علاقه خود را انتخاب کنید:")
label.pack(pady=10)

# دکمه‌های CheckButton
python_check = tk.Checkbutton(root, text="پایتون", variable=python_var)
java_check = tk.Checkbutton(root, text="جاوا", variable=java_var)
cpp_check = tk.Checkbutton(root, text="C++", variable=cpp_var)

python_check.pack(pady=5)
java_check.pack(pady=5)
cpp_check.pack(pady=5)

# دکمه برای نمایش انتخاب‌ها
button = tk.Button(root, text="نمایش انتخاب‌ها", command=show_selections)
button.pack(pady=10)

# اجرای حلقه اصلی برنامه
root.mainloop()

# %%
import tkinter as tk
from tkinter import messagebox

# تابع محاسبه میانگین
def calculate_average():
    # try:
        # دریافت ورودی از کاربر و تبدیل به لیست
        numbers = list(map(float, entry.get().split()))
        # محاسبه میانگین
        average = sum(numbers) / len(numbers)
        # نمایش میانگین
        result_label.config(text=f"میانگین: {average}",fg="red",background="yellow",font=("B Nazanin",32))
        
        
    # except ValueError:
    #     # اگر ورودی نامعتبر بود، پیام خطا نشان بده
    #     messagebox.showerror("خطا", "لطفاً فقط اعداد وارد کنید!")


def delete_entry():
    entry.delete(0, tk.END)



# ایجاد پنجره اصلی
root = tk.Tk()


root.title("محاسبه میانگین")

# برچسب توضیح
label = tk.Label(root, text="لطفاً اعداد خود را با فاصله وارد کنید:")

# ورودی کاربر
entry = tk.Entry(root, width=35)

# دکمه برای محاسبه میانگین
button = tk.Button(root, text="محاسبه میانگین", command=calculate_average)


button2 = tk.Button(root, text="پاک کردن ورودی", command=delete_entry)


# برچسب نمایش نتیجه
result_label = tk.Label(root, text="میانگین هنوز محاسبه نشده است")


label.pack(pady=10)
entry.pack(pady=10,padx=10)
button.pack(pady=10)
button2.pack(pady=10)
result_label.pack(pady=10)



# اجرای حلقه اصلی برنامه
root.mainloop()

# %%
import tkinter as tk
from tkinter import messagebox
from tkinter import ttk
import sqlite3

# ایجاد یا اتصال به دیتابیس SQLite
conn = sqlite3.connect('students.db')
c = conn.cursor()

# ایجاد جدول در دیتابیس (در صورت عدم وجود)
c.execute('''
CREATE TABLE IF NOT EXISTS students (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    name TEXT NOT NULL,
    major TEXT NOT NULL
)
''')
conn.commit()

# تابع برای ذخیره کردن دانشجویان در دیتابیس
def save_student():
    name = entry_name.get()
    major = entry_major.get()
    
    if name and major:
        c.execute("INSERT INTO students (name, major) VALUES (?, ?)", (name, major))
        conn.commit()
        messagebox.showinfo("Success", "Student added successfully!")
        entry_name.delete(0, tk.END)
        entry_major.delete(0, tk.END)
    else:
        messagebox.showwarning("Input error", "Please fill both fields")

# تابع برای باز کردن پنجره‌ی نمایش لیست دانشجویان
def show_students():
    # ایجاد یک پنجره‌ی جدید
    root2 = tk.Toplevel(root)
    root2.title("Student List")
    

 

    # ایجاد جدول
    tree = ttk.Treeview(root2, columns=("ID", "Name", "Major"), show="headings")
    tree.heading("ID", text="آیدی")
    tree.heading("Name", text="نام")
    tree.heading("Major", text="رشته")
    
    tree.pack(fill=tk.BOTH, expand=False)

    # واکشی اطلاعات از دیتابیس و پر کردن جدول
    c.execute("SELECT * FROM students")
    rows = c.fetchall()
    
    for x in rows:
        tree.insert("", tk.END, values=x)

# رابط کاربری اصلی
root = tk.Tk()
root.title("Student Management")

# فریم برای فرم ورود اطلاعات
frame = tk.Frame(root)
frame.pack(pady=20)

tk.Label(frame, text="Student Name").grid(row=0, column=0, padx=10, pady=10)
tk.Label(frame, text="Major").grid(row=1, column=0, padx=10, pady=10)

entry_name = tk.Entry(frame)
entry_name.grid(row=0, column=1, padx=10, pady=10)

entry_major = tk.Entry(frame)
entry_major.grid(row=1, column=1, padx=10, pady=10)

btn_save = tk.Button(frame, text="Save Student", command=save_student)
btn_save.grid(row=2, columnspan=2, pady=20)

btn_show = tk.Button(root, text="Show Students", command=show_students)
btn_show.pack(pady=10)

root.mainloop()

# بستن اتصال به دیتابیس در انتهای برنامه
conn.close()

# %%
import tkinter as tk  # وارد کردن کتابخانه tkinter برای ساخت رابط کاربری گرافیکی

# تابع برای مدیریت کلیک دکمه‌ها (برای اعداد و عملگرها)
def button_click(number):
    current = entry.get()  # گرفتن متن فعلی از ویجت ورودی
    entry.delete(0, tk.END)  # پاک کردن ویجت ورودی
    entry.insert(0, str(current) + str(number))  # درج متن جدید (عدد یا عملگر کلیک شده) در ورودی

# این تابع زمانی فراخوانی می‌شود که یک دکمه (عددی یا عملگری) کلیک شود. ابتدا متن فعلی ورودی را می‌گیرد، سپس آن را پاک کرده و متن جدید (عدد یا عملگر) را اضافه می‌کند.


# تابع برای پاک کردن محتوای ورودی
def button_clear():
    entry.delete(0, tk.END)  # پاک کردن تمام محتوای ویجت ورودی

# تابع برای محاسبه نتیجه و نمایش آن
def button_equal():
    try:
        result = str(eval(entry.get()))  # ارزیابی و محاسبه عبارت ریاضی از ورودی
        entry.delete(0, tk.END)  # پاک کردن ورودی قبلی
        entry.insert(0, result)  # نمایش نتیجه در ویجت ورودی
    except:
        entry.delete(0, tk.END)  # در صورت خطا، ورودی را پاک کن
        entry.insert(0, "خطا!")  # نمایش پیغام "خطا!" در صورت وجود مشکل


# این تابع زمانی فراخوانی می‌شود که دکمه = کلیک شود. ابتدا سعی می‌کند با استفاده از تابع eval محتوای ورودی را به عنوان یک عبارت ریاضی ارزیابی کند. اگر محاسبه موفقیت‌آمیز بود، نتیجه نمایش داده می‌شود، وگرنه پیغام "خطا!" نمایش داده می‌شود.



root = tk.Tk()  # ساخت پنجره اصلی برنامه با استفاده از tkinter
root.title("ماشین حساب")  # تنظیم عنوان پنجره به "ماشین حساب"

# ساخت یک ویجت ورودی برای نمایش و ورود اعداد
entry = tk.Entry(root, width=35, borderwidth=5)
entry.grid(row=0, column=0, columnspan=4)  # قرار دادن ویجت ورودی در شبکه (grid)

# لیستی از دکمه‌های ماشین حساب (اعداد و عملگرها)
buttons = [
    '7', '8', '9', '/',
    '4', '5', '6', '*',
    '1', '2', '3', '-',
    '0', '.', '=', '+'
]

row_val = 1  # شماره سطر برای دکمه‌ها
col_val = 0  # شماره ستون برای دکمه‌ها

# ساخت و قرار دادن دکمه‌ها در پنجره
for button in buttons:
    action = lambda x=button: button_click(x) if x != '=' else button_equal()  # تعیین عملکرد دکمه (اگر '=' باشد، تابع button_equal را فراخوانی کن، در غیر این صورت button_click)
    tk.Button(root, text=button, width=9, height=3, command=action).grid(row=row_val, column=col_val)  # ساخت دکمه و قرار دادن آن در شبکه
    col_val += 1  # حرکت به ستون بعدی
    if col_val > 3:  # اگر ستون‌ها پر شد، به سطر بعدی برو
        col_val = 0  # تنظیم شماره ستون به 0
        row_val += 1  # افزایش شماره سطر

# ساخت دکمه "پاک کردن" و قرار دادن آن در پنجره
tk.Button(root, text="پاک کردن", width=9, height=3, command=button_clear).grid(row=row_val, columnspan=4)

root.mainloop()  # اجرای حلقه اصلی برنامه برای نمایش پنجره و مدیریت رویدادها

# %%
from tkinter import *
# ماژول Tkinter را وارد می‌کنیم که برای ایجاد رابط‌های کاربری گرافیکی در پایتون استفاده می‌شود.

def btnClick(numbers):
    global operator
    # این تابع وقتی دکمه‌های عددی یا عملیاتی کلیک شوند اجرا می‌شود.
    operator = operator + str(numbers)
    # عدد یا عملگر کلیک شده را به زنجیره عملیات اضافه می‌کند.
    text_input.set(operator)
    # مقدار جدید را در نمایشگر ماشین حساب نشان می‌دهد.

def btnClearDisplay():
    global operator
    # این تابع نمایشگر را پاک می‌کند.
    operator = ""
    # زنجیره عملیات را خالی می‌کند.
    text_input.set("")
    # نمایشگر را به صورت خالی نشان می‌دهد.

def btnEqualsInput():
    global operator
    # این تابع زمانی که دکمه "برابر" (=) فشرده می‌شود اجرا می‌شود.
    sumup = str(eval(operator))
    # از تابع eval برای محاسبه عملیات استفاده می‌شود.
    text_input.set(sumup)
    # نتیجه عملیات در نمایشگر نشان داده می‌شود.
    operator = ""
    # پس از محاسبه، زنجیره عملیات پاک می‌شود.

cal = Tk()
# یک پنجره اصلی برای ماشین حساب ایجاد می‌کند.
cal.title("Calculator")
# عنوان پنجره ماشین حساب را تنظیم می‌کند.

operator = ""
# متغیری برای نگهداری زنجیره عملیات تعریف می‌کنیم.

text_input = StringVar()
# متغیری از نوع StringVar برای نگهداری مقدار نمایشگر ماشین حساب تعریف می‌کنیم.

txtDisplay = Entry(cal, font=('arial', 20, 'bold'), textvariable=text_input, bd=30,
                   insertwidth=4, bg='powder blue', justify='right').grid(columnspan=4)
# یک فیلد ورودی (نمایشگر) برای ماشین حساب با فونت، حاشیه و رنگ خاص ایجاد می‌کند. 
# این فیلد ورودی در ۴ ستون نمایش داده می‌شود.

#============================================================================
# دکمه‌های مربوط به اعداد و عملیات:
btn7 = Button(cal, padx=16, pady=16, bd=8, fg='black', font=('arial', 20, 'bold'),
              text='7', command=lambda:btnClick(7)).grid(row=1, column=0)
# دکمه‌ای برای عدد 7 ایجاد می‌شود که در ردیف 1 و ستون 0 قرار می‌گیرد.
btn8 = Button(cal, padx=16, pady=16, bd=8, fg='black', font=('arial', 20, 'bold'),
              text='8', command=lambda:btnClick(8)).grid(row=1, column=1)
# دکمه‌ای برای عدد 8 ایجاد می‌شود که در ردیف 1 و ستون 1 قرار می‌گیرد.
btn9 = Button(cal, padx=16, pady=16, bd=8, fg='black', font=('arial', 20, 'bold'),
              text='9', command=lambda:btnClick(9)).grid(row=1, column=2)
# دکمه‌ای برای عدد 9 ایجاد می‌شود که در ردیف 1 و ستون 2 قرار می‌گیرد.
addition = Button(cal, padx=16, pady=16, bd=8, fg='black', font=('arial', 20, 'bold'),
              text='+', command=lambda:btnClick('+')).grid(row=1, column=3)
# دکمه‌ای برای عملگر جمع (+) ایجاد می‌شود که در ردیف 1 و ستون 3 قرار می‌گیرد.

#============================================================================
btn4 = Button(cal, padx=16, pady=16, bd=8, fg='black', font=('arial', 20, 'bold'),
              text='4', command=lambda:btnClick(4)).grid(row=2, column=0)
# دکمه‌ای برای عدد 4 ایجاد می‌شود که در ردیف 2 و ستون 0 قرار می‌گیرد.
btn5 = Button(cal, padx=16, pady=16, bd=8, fg='black', font=('arial', 20, 'bold'),
              text='5', command=lambda:btnClick(5)).grid(row=2, column=1)
# دکمه‌ای برای عدد 5 ایجاد می‌شود که در ردیف 2 و ستون 1 قرار می‌گیرد.
btn6 = Button(cal, padx=16, pady=16, bd=8, fg='black', font=('arial', 20, 'bold'),
              text='6', command=lambda:btnClick(6)).grid(row=2, column=2)
# دکمه‌ای برای عدد 6 ایجاد می‌شود که در ردیف 2 و ستون 2 قرار می‌گیرد.
subtraction = Button(cal, padx=16, pady=16, bd=8, fg='black', font=('arial', 20, 'bold'),
              text='-', command=lambda:btnClick('-')).grid(row=2, column=3)
# دکمه‌ای برای عملگر تفریق (-) ایجاد می‌شود که در ردیف 2 و ستون 3 قرار می‌گیرد.

#============================================================================
btn1 = Button(cal, padx=16, pady=16, bd=8, fg='black', font=('arial', 20, 'bold'),
              text='1', command=lambda:btnClick(1)).grid(row=3, column=0)
# دکمه‌ای برای عدد 1 ایجاد می‌شود که در ردیف 3 و ستون 0 قرار می‌گیرد.
btn2 = Button(cal, padx=16, pady=16, bd=8, fg='black', font=('arial', 20, 'bold'),
              text='2', command=lambda:btnClick(2)).grid(row=3, column=1)
# دکمه‌ای برای عدد 2 ایجاد می‌شود که در ردیف 3 و ستون 1 قرار می‌گیرد.
btn3 = Button(cal, padx=16, pady=16, bd=8, fg='black', font=('arial', 20, 'bold'),
              text='3', command=lambda:btnClick(3)).grid(row=3, column=2)
# دکمه‌ای برای عدد 3 ایجاد می‌شود که در ردیف 3 و ستون 2 قرار می‌گیرد.
multiply = Button(cal, padx=16, pady=16, bd=8, fg='black', font=('arial', 20, 'bold'),
              text='*', command=lambda:btnClick('*')).grid(row=3, column=3)
# دکمه‌ای برای عملگر ضرب (*) ایجاد می‌شود که در ردیف 3 و ستون 3 قرار می‌گیرد.

#============================================================================
btn0 = Button(cal, padx=16, pady=16, bd=8, fg='black', font=('arial', 20, 'bold'),
              text='0', command=lambda:btnClick(0)).grid(row=4, column=0)
# دکمه‌ای برای عدد 0 ایجاد می‌شود که در ردیف 4 و ستون 0 قرار می‌گیرد.
btnClear = Button(cal, padx=16, pady=16, bd=8, fg='black', font=('arial', 20, 'bold'),
              text='C', command=btnClearDisplay).grid(row=4, column=1)
# دکمه‌ای برای پاک کردن (C) ایجاد می‌شود که در ردیف 4 و ستون 1 قرار می‌گیرد.
btnEquals = Button(cal, padx=16, pady=16, bd=8, fg='black', font=('arial', 20, 'bold'),
              text='=', command=btnEqualsInput).grid(row=4, column=2)
# دکمه‌ای برای محاسبه نتیجه (=) ایجاد می‌شود که در ردیف 4 و ستون 2 قرار می‌گیرد.
division = Button(cal, padx=16, pady=16, bd=8, fg='black', font=('arial', 20, 'bold'),
              text='/', command=lambda:btnClick('/')).grid(row=4, column=3)
# دکمه‌ای برای عملگر تقسیم (/) ایجاد می‌شود که در ردیف 4 و ستون 3 قرار می‌گیرد.

cal.mainloop()
# حلقه اصلی برنامه برای اجرا و نمایش پنجره ماشین حساب شروع می‌شود.

# %% [markdown]
# توضیحات تکمیلی

# %% [markdown]
# 1. Entry(cal, ...):
# Entry: این یک ویجت (ابزارک) از کتابخانه Tkinter است که برای نمایش و دریافت ورودی متنی در رابط کاربری گرافیکی استفاده می‌شود. در اینجا برای نمایش اعداد و نتایج محاسبات در ماشین حساب به کار می‌رود.
# cal: این اولین آرگومان، نام پنجره یا فریم والد (در اینجا cal که شیء اصلی پنجره است) را مشخص می‌کند که این فیلد ورودی در آن قرار می‌گیرد.
# 2. font=('arial', 20, 'bold'):
# font: مشخصات فونت متن داخل فیلد ورودی را تعیین می‌کند.
# 'arial': نام فونت را مشخص می‌کند (در اینجا فونت Arial).
# 20: اندازه فونت را مشخص می‌کند (در اینجا اندازه فونت 20 است).
# 'bold': استایل فونت را مشخص می‌کند (در اینجا فونت به صورت ضخیم یا Bold است).
# 3. textvariable=text_input:
# textvariable: این پارامتر تعیین می‌کند که محتوای فیلد ورودی با یک متغیر در ارتباط باشد.
# text_input: این متغیری از نوع StringVar() است که محتوای فیلد ورودی را ذخیره و مدیریت می‌کند. با استفاده از این متغیر، می‌توان مقدار فیلد ورودی را به راحتی تغییر داد یا خواند.
# 4. bd=30:
# bd (Border Width): این پارامتر تعیین می‌کند که عرض حاشیه (border) اطراف فیلد ورودی چند پیکسل باشد. در اینجا حاشیه 30 پیکسل است که به وضوح باعث بزرگتر شدن کادر نمایشگر می‌شود.
# 5. insertwidth=4:
# insertwidth: این پارامتر عرض نشانگر چشمک‌زن (caret) که در هنگام وارد کردن یا نمایش متن ظاهر می‌شود را تنظیم می‌کند. مقدار 4 به این معنی است که عرض نشانگر 4 پیکسل خواهد بود.
# 6. bg='powder blue':
# bg (Background): این پارامتر رنگ پس‌زمینه فیلد ورودی را تعیین می‌کند. در اینجا از رنگ powder blue (آبی کم‌رنگ) برای پس‌زمینه استفاده شده است.
# 7. justify='right':
# justify: نحوه تراز کردن متن داخل فیلد ورودی را مشخص می‌کند. مقدار 'right' به این معنی است که متن از سمت راست فیلد ورودی تراز می‌شود. این ویژگی مناسب نمایش اعداد در ماشین حساب است، زیرا معمولاً اعداد در ماشین حساب‌ها از سمت راست وارد می‌شوند.
# 8. .grid(columnspan=4):
# grid(): این یک متد برای قرار دادن ویجت‌ها در رابط کاربری با استفاده از یک سیستم شبکه‌ای (grid) است. در اینجا از grid() برای تنظیم موقعیت فیلد ورودی در رابط کاربری استفاده می‌شود.
# columnspan=4: این پارامتر مشخص می‌کند که این فیلد ورودی باید به اندازه ۴ ستون در رابط کاربری گسترش یابد. چون ماشین حساب در کل ۴ ستون دارد، این ویژگی باعث می‌شود که فیلد ورودی در بالای ماشین حساب به صورت کامل (در تمام ۴ ستون) نمایش داده شود.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # --- Session 13 ---
# # tkInter (Example)
# # واسط گرافیکی tkInter + Example

# %% [markdown]
# sticky="nsew":
# پارامتر sticky به ما این امکان را می‌دهد که دکمه‌ها را در جهات مختلف بکشیم. در مثال بالا، با استفاده از sticky="nsew"، دکمه 2 به تمام فضای شبکه (north, south, east, west) کشیده می‌شود.

# %%
import tkinter as tk

root = tk.Tk()
root.geometry("600x300")

# ایجاد دکمه‌ها
btn1 = tk.Button(root, text="Button 1", padx=20, pady=10)
btn2 = tk.Button(root, text="Button 2", padx=20, pady=10)
btn3 = tk.Button(root, text="Button 3", padx=20, pady=10)

# قرار دادن دکمه‌ها در شبکه (grid)
btn1.grid(row=0, column=0)  # دکمه 1 در ستون 0 و ردیف 0
btn2.grid(row=0, column=1, columnspan=2, sticky="nsew")  # دکمه 2 دو ستون را اشغال می‌کند
btn3.grid(row=0, column=3)  # دکمه 3 در ستون 3

# تنظیم کشش ستون‌ها
root.grid_columnconfigure(0, weight=1)
root.grid_columnconfigure(1, weight=1)
root.grid_columnconfigure(2, weight=1)
root.grid_columnconfigure(3, weight=1)

root.mainloop()

# %% [markdown]
# مرحله 1: ایجاد پنجره اصلی و تنظیمات اولیه

# %%
import tkinter as tk

# ایجاد پنجره اصلی
root = tk.Tk()  # ایجاد پنجره
root.title("ماشین حساب زیبا")  # تنظیم عنوان پنجره
root.geometry("400x600")  # تنظیم اندازه پنجره
root.config(bg="#1e1e1e")  # تنظیم پس‌زمینه تیره

root.mainloop()  # اجرای برنامه

# %% [markdown]
# مرحله 2: ایجاد نمایشگر ماشین حساب

# %%
import tkinter as tk

# ایجاد پنجره اصلی
root = tk.Tk()
root.title("ماشین حساب زیبا")
root.geometry("400x600")
root.config(bg="#1e1e1e")

# استایل نمایشگر
display = tk.Entry(root, font=("Helvetica", 32), bg="#1e1e1e", fg="#ffffff", bd=0, justify="right", insertbackground="#ffffff")
display.grid(row=0, column=0, columnspan=4, padx=10, pady=20, ipady=10)  # قرار دادن نمایشگر در بالا

root.mainloop()

# %% [markdown]
# مرحله 3: افزودن دکمه‌های اعداد و عملیات

# %%
import tkinter as tk

# ایجاد پنجره اصلی
root = tk.Tk()
root.title("ماشین حساب زیبا")
root.geometry("400x600")
root.config(bg="#1e1e1e")

# استایل نمایشگر
display = tk.Entry(root, font=("Helvetica", 32), bg="#1e1e1e", fg="#ffffff", bd=0, justify="right", insertbackground="#ffffff")
display.grid(row=0, column=0, columnspan=4, padx=10, pady=20, ipady=10)

# استایل دکمه‌ها
button_font = ("Helvetica", 18)
button_color = "#2e2e2e"
button_text_color = "#ffffff"
button_active_color = "#4e4e4e"

# تابع برای نمایش اعداد
def button_click(number):
    current = display.get()
    display.delete(0, tk.END)
    display.insert(0, current + str(number))

# ایجاد دکمه‌های اعداد و عملیات
button_texts = [
    ('7', 2, 0), ('8', 2, 1), ('9', 2, 2), ('+', 2, 3),
    ('4', 3, 0), ('5', 3, 1), ('6', 3, 2), ('-', 3, 3),
    ('1', 4, 0), ('2', 4, 1), ('3', 4, 2), ('*', 4, 3),
    ('0', 5, 0, 2), ('.', 5, 2), ('/', 5, 3)
]

for (text, row, col, *span) in button_texts:
    span = span[0] if span else 1
    btn = tk.Button(root, text=text, font=button_font, bg=button_color, fg=button_text_color, activebackground=button_active_color, bd=0, padx=20, pady=20)
    btn.config(command=lambda t=text: button_click(t))
    btn.grid(row=row, column=col, columnspan=span, sticky="nsew", padx=5, pady=5)

root.mainloop()

# %% [markdown]
# مرحله 4: افزودن دکمه پاک کردن و برابر

# %%
import tkinter as tk

# ایجاد پنجره اصلی
root = tk.Tk()
root.title("ماشین حساب زیبا")
root.geometry("400x600")
root.config(bg="#1e1e1e")

# استایل نمایشگر
display = tk.Entry(root, font=("Helvetica", 32), bg="#1e1e1e", fg="#ffffff", bd=0, justify="right", insertbackground="#ffffff")
display.grid(row=0, column=0, columnspan=4, padx=10, pady=20, ipady=10)

# استایل دکمه‌ها
button_font = ("Helvetica", 18)
button_color = "#2e2e2e"
button_text_color = "#ffffff"
button_active_color = "#4e4e4e"

# تابع برای نمایش اعداد
def button_click(number):
    current = display.get()
    display.delete(0, tk.END)
    display.insert(0, current + str(number))

# تابع پاک کردن نمایشگر
def button_clear():
    display.delete(0, tk.END)

# تابع محاسبه نتیجه
def button_equal():
    try:
        result = str(eval(display.get()))  # محاسبه و نمایش نتیجه
        display.delete(0, tk.END)
        display.insert(0, result)
    except:
        display.delete(0, tk.END)
        display.insert(0, "خطا")

# ایجاد دکمه‌های اعداد و عملیات
button_texts = [
    ('C', 1, 0), ('/', 1, 1), ('*', 1, 2), ('-', 1, 3),
    ('7', 2, 0), ('8', 2, 1), ('9', 2, 2), ('+', 2, 3),
    ('4', 3, 0), ('5', 3, 1), ('6', 3, 2), ('=', 3, 3, 2),
    ('1', 4, 0), ('2', 4, 1), ('3', 4, 2),
    ('0', 5, 0, 2), ('.', 5, 2),
]

for (text, row, col, *span) in button_texts:
    span = span[0] if span else 1
    btn = tk.Button(root, text=text, font=button_font, bg=button_color, fg=button_text_color, activebackground=button_active_color, bd=0, padx=20, pady=20)
    
    if text.isdigit() or text == ".":
        btn.config(command=lambda t=text: button_click(t))
    elif text == 'C':
        btn.config(command=button_clear)
    elif text == '=':
        btn.config(command=button_equal)
    else:
        btn.config(command=lambda t=text: button_click(t))
    
    btn.grid(row=row, column=col, columnspan=span, sticky="nsew", padx=5, pady=5)

root.mainloop()

# %% [markdown]
# مرحله 5: تنظیم کشش ردیف‌ها و ستون‌ها

# %%
import tkinter as tk

# ایجاد پنجره اصلی
root = tk.Tk()
root.title("ماشین حساب زیبا")
root.geometry("400x600")
root.config(bg="#1e1e1e")


root.iconbitmap("images/a.ico")  # تغییر آیکون برنامه با فایل icon.ico


# استایل نمایشگر
display = tk.Entry(root, font=("Helvetica", 32), bg="#1e1e1e", fg="#ffffff", bd=0, justify="right", insertbackground="#ffffff")
display.grid(row=0, column=0, columnspan=4, padx=10, pady=20, ipady=10)

# استایل دکمه‌ها
button_font = ("Helvetica", 18)
button_color = "#2e2e2e"
button_text_color = "#ffffff"
button_active_color = "#4e4e4e"

# تابع برای نمایش اعداد
def button_click(number):
    current = display.get()
    display.delete(0, tk.END)
    display.insert(0, current + str(number))

# تابع پاک کردن نمایشگر
def button_clear():
    display.delete(0, tk.END)

# تابع محاسبه نتیجه
def button_equal():
    try:
        result = str(eval(display.get()))  # محاسبه و نمایش نتیجه
        display.delete(0, tk.END)
        display.insert(0, result)
    except:
        display.delete(0, tk.END)
        display.insert(0, "خطا")

# ایجاد دکمه‌های اعداد و عملیات
button_texts = [
    ('C', 1, 0), ('/', 1, 1), ('*', 1, 2), ('-', 1, 3),
    ('7', 2, 0), ('8', 2, 1), ('9', 2, 2), ('+', 2, 3),
    ('4', 3, 0), ('5', 3, 1), ('6', 3, 2), ('=', 3, 3 ),
    ('1', 4, 0), ('2', 4, 1), ('3', 4, 2),
    ('0', 5, 0, 2), ('.', 5, 2),
]

for (text, row, col, *span) in button_texts:
    span = span[0] if span else 1
    btn = tk.Button(root, text=text, font=button_font, bg=button_color, fg=button_text_color, activebackground=button_active_color, bd=0, padx=20, pady=20)
    
    if text.isdigit() or text == ".":
        btn.config(command=lambda t=text: button_click(t))
    elif text == 'C':
        btn.config(command=button_clear)
    elif text == '=':
        btn.config(command=button_equal)
    else:
        btn.config(command=lambda t=text: button_click(t))
    
    btn.grid(row=row, column=col, columnspan=span, sticky="nsew", padx=5, pady=5)

# تنظیم کشش ستون‌ها و ردیف‌ها
for i in range(4):
    root.grid_columnconfigure(i, weight=1)  # کشش ستون‌ها
for i in range(6):
    root.grid_rowconfigure(i, weight=1)  # کشش ردیف‌ها

root.mainloop()

# %%
import tkinter as tk

# ایجاد پنجره اصلی
# با استفاده از Tkinter یک پنجره اصلی به نام root ساخته می‌شود
root = tk.Tk()
root.title("ماشین حساب زیبا")  # عنوان پنجره
root.geometry("400x600")  # تنظیم اندازه پنجره به عرض 400 و ارتفاع 600
root.config(bg="#1e1e1e")  # تنظیم رنگ پس‌زمینه پنجره به رنگ تیره (برای ظاهری مدرن)

# استایل نمایشگر
# نمایشگر ماشین‌حساب که ورودی‌ها و خروجی‌ها در آن نمایش داده می‌شود (Entry widget)
display = tk.Entry(root, font=("Helvetica", 32), bg="#1e1e1e", fg="#ffffff", bd=0, justify="right", insertbackground="red")
# font: فونت و اندازه متن
# bg: رنگ پس‌زمینه نمایشگر
# fg: رنگ متن (عدد)
# bd: بدون border
# justify: تراز کردن متن به سمت راست
# insertbackground: رنگ نشانگر هنگام تایپ
display.grid(row=0, column=0, columnspan=4, padx=100, pady=20, ipady=10)
# grid: قرار دادن نمایشگر در پنجره با استفاده از سیستم grid
# row: ردیف قرارگیری
# column: ستون قرارگیری
# columnspan: تعداد ستون‌هایی که نمایشگر اشغال می‌کند (4 ستون)
# padx و pady: فاصله‌های داخلی از اطراف
# ipady: افزایش ارتفاع داخلی نمایشگر

# استایل دکمه‌ها
button_font = ("Helvetica", 18)  # تنظیم فونت و اندازه متن دکمه‌ها
button_color = "#2e2e2e"  # رنگ پس‌زمینه دکمه‌ها
button_text_color = "#ffffff"  # رنگ متن دکمه‌ها
button_active_color = "#4e4e4e"  # رنگ پس‌زمینه دکمه‌ها در حالت فعال (زمانی که فشرده می‌شوند)

# تابع برای نمایش اعداد در نمایشگر
def button_click(number):
    current = display.get()  # دریافت مقدار فعلی از نمایشگر
    display.delete(0, tk.END)  # پاک کردن مقدار قبلی در نمایشگر
    display.insert(0, current + str(number))  # افزودن عدد جدید به انتهای مقدار قبلی

# تابع برای پاک کردن نمایشگر
def button_clear():
    display.delete(0, tk.END)  # پاک کردن تمامی متن از نمایشگر

# تابع محاسبه نتیجه
def button_equal():
    try:
        result = str(eval(display.get()))  # ارزیابی عبارت ریاضی وارد شده توسط کاربر و تبدیل آن به رشته
        display.delete(0, tk.END)  # پاک کردن مقدار قبلی
        display.insert(0, result)  # نمایش نتیجه محاسبه
    except:
        display.delete(0, tk.END)  # در صورت بروز خطا، پاک کردن نمایشگر
        display.insert(0, "خطا")  # نمایش پیام خطا در نمایشگر

# ایجاد دکمه‌های اعداد و عملیات ریاضی
# یک لیست از دکمه‌های مختلف با متن، ردیف و ستون مربوطه ساخته شده
button_texts = [
    ('C', 1, 0), ('/', 1, 1), ('*', 1, 2), ('-', 1, 3),
    ('7', 2, 0), ('8', 2, 1), ('9', 2, 2), ('+', 2, 3),
    ('4', 3, 0), ('5', 3, 1), ('6', 3, 2), ('=', 3, 3 ),
    ('1', 4, 0), ('2', 4, 1), ('3', 4, 2),
    ('0', 5, 0, 2), ('.', 5, 2),
]

# این حلقه برای ایجاد و تنظیم دکمه‌های ماشین‌حساب است
for (text, row, col, *span) in button_texts:
    span = span[0] if span else 1  # اگر span تعیین شده بود، آن را می‌گیرد وگرنه 1 (یعنی یک ستون)
    # ایجاد دکمه با متن و تنظیمات مشخص
    btn = tk.Button(root, text=text, font=button_font, bg=button_color, fg=button_text_color, activebackground=button_active_color, bd=0, padx=20, pady=20)
    
    # اگر دکمه عدد یا '.' باشد، تابع button_click برای کلیک شدن تنظیم می‌شود
    if text.isdigit() or text == ".":
        btn.config(command=lambda t=text: button_click(t))
    # اگر دکمه 'C' باشد، تابع button_clear برای پاک کردن استفاده می‌شود
    elif text == 'C':
        btn.config(command=button_clear)
    # اگر دکمه '=' باشد، تابع button_equal برای محاسبه نتیجه استفاده می‌شود
    elif text == '=':
        btn.config(command=button_equal)
    # سایر دکمه‌ها (مانند عملیات ریاضی) هم به تابع button_click متصل می‌شوند
    else:
        btn.config(command=lambda t=text: button_click(t))
    
    # قرار دادن دکمه در پنجره با استفاده از grid
    btn.grid(row=row, column=col, columnspan=span, sticky="nsew", padx=5, pady=5)

# تنظیم کشش ستون‌ها و ردیف‌ها
for i in range(4):
    root.grid_columnconfigure(i, weight=1)  # تنظیم ستون‌ها برای کشش یکنواخت و پر کردن فضا
for i in range(6):
    root.grid_rowconfigure(i, weight=1)  # تنظیم ردیف‌ها برای کشش یکنواخت و پر کردن فضا

# اجرای اصلی برنامه
root.mainloop()  # شروع اجرای برنامه و نمایش پنجره تا زمان بسته شدن
